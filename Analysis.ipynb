# %%
import pandas as pd

# %%
db = pd.read_json('data.json')

# %%
db.head()
# Out:
#                                                title         type  \
# 0  'Mini-stroke' or transient ischaemic attack (TIA)      symptom
# 1                                     6-in-1 vaccine  vaccination
# 2                     Abdominal pain (biliary colic)      symptom
# 3             Abnormal cells in the cervix or vagina        other
# 4                             Abnormal pain messages      symptom
#
#                                                 data         disease
# 0  [<p>The symptoms of a TIA are the same as a st...          Stroke
# 1  [<p>The 6-in-1 vaccine, also known as the DTaP...      Meningitis
# 2  [<p>Gallstones can cause sudden, severe abdomi...      Gallstones
# 3  [<p>You're more likely to develop vaginal canc...  Vaginal cancer
# 4  [<p>One of the main theories is that people wi...    Fibromyalgia

# %%
db.loc[db['type'] == 'vaccination']
# Out:
#                                        title         type  \
# 1                             6-in-1 vaccine  vaccination
# 911              Cervical cancer vaccination  vaccination
# 2029                 Hepatitis A vaccination  vaccination
# 2450  Is there a vaccine against chickenpox?  vaccination
# 2680                             MMR vaccine  vaccination
# 3197                    Pneumococcal vaccine  vaccination
# 3634                   Rotavirus vaccination  vaccination
# 4455                    The shingles vaccine  vaccination
# 4468                         The flu vaccine  vaccination
# 4981                Tuberculosis vaccination  vaccination
# 5003            Types of hepatitis A vaccine  vaccination
# 5061                             Vaccination  vaccination
# 5062                             Vaccination  vaccination
# 5063                            Vaccinations  vaccination
# 5064                            Vaccinations  vaccination
# ...

# %%
db.loc[db['type'] == 'symptom']
# Out:
#                                                   title     type  \
# 0     'Mini-stroke' or transient ischaemic attack (TIA)  symptom
# 2                        Abdominal pain (biliary colic)  symptom
# 4                                Abnormal pain messages  symptom
# 216                                        About stroke  symptom
# 273             Additional problems in adults with ADHD  symptom
# ...                                                 ...      ...
# 5678                                      Your feelings  symptom
# 5679                                      Your feelings  symptom
# 5680                                      Your feelings  symptom
# 5707                 ​Symptoms and causes of depression  symptom
# 5708                            ​Symptoms and diagnosis  symptom
#
#                                                    data  \
# 0     [<p>The symptoms of a TIA are the same as a st...
# 2     [<p>Gallstones can cause sudden, severe abdomi...
# ...
